# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
perf = pd.read_csv('performances.csv')
perf = perf.drop(columns=['Unnamed: 0'])
perf
# Out:
#       program_used     dataset_used  success  \
# 0          problem     B with zeros     True
# 1            v10.2     B with zeros    False
# 2   v10.2noparents     B with zeros     True
# 3          problem     C with zeros     True
# 4            v10.2     C with zeros     True
# 5   v10.2noparents     C with zeros     True
# 6          problem  B without zeros     True
# 7            v10.2  B without zeros    False
# 8   v10.2noparents  B without zeros     True
# 9          problem  C without zeros     True
# 10           v10.2  C without zeros     True
# 11  v10.2noparents  C without zeros     True
#
#                                               answers     time
# 0   ['selgene(lgals1)', 'selgene(aes)', 'selgene(s...    2.334
# 1                                                  []    0.072
# 2   ['affinity(e510933,e5121033)', 'affinity(e5109...    0.111
# 3   ['selgene(lgals1)', 'selgene(aes)', 'selgene(e...   95.560
# ...

# %%
perf[['program_used', 'dataset_used', 'time']].groupby(['program_used','dataset_used']).mean()
# Out:
#                                    time
# program_used   dataset_used
# problem        B with zeros       2.334
#                B without zeros    1.220
#                C with zeros      95.560
#                C without zeros  147.000
# v10.2          B with zeros       0.072
#                B without zeros    0.046
#                C with zeros       0.444
#                C without zeros    0.311
# v10.2noparents B with zeros       0.111
#                B without zeros    0.055
#                C with zeros       0.581
#                C without zeros    0.472

# %%
perf_v2 = pd.read_csv('performances_v2.csv',sep=';')
perf_v2 = perf_v2.drop(columns=['index'])
perf_v2
# Out:
#       program_used     dataset_used  ram  k  nb_genes  search_space  success  \
# 0          problem     B_with_zeros   16  3        30          4060        1
# 1            v10.2     B_with_zeros   16  3        30          4060        0
# 2   v10.2noparents     B_with_zeros   16  3        30          4060        1
# 3   v10.2noparents     B_with_zeros    4  3        30          4060        1
# 4          problem     C_with_zeros   16  3       100        161700        1
# 5            v10.2     C_with_zeros   16  3       100        161700        1
# 6   v10.2noparents     C_with_zeros   16  3       100        161700        1
# 7   v10.2noparents     C_with_zeros    4  3       100        161700        1
# 8          problem  B_without_zeros   16  3        18           816        1
# 9            v10.2  B_without_zeros   16  3        18           816        0
# 10  v10.2noparents  B_without_zeros   16  3        18           816        1
# ...

# %%
perf_v2.groupby('program_used')#.plot(x='search_space',y='time',legend='dataset_used')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/mambaforge/envs/PAPYTP/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File ~/mambaforge/envs/PAPYTP/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/mambaforge/envs/PAPYTP/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...
